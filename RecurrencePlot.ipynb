# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint,quad,trapz
import math
from IPython.display import Image # for Notebook
from IPython.core.display import HTML
from mpl_toolkits.mplot3d import Axes3D

sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -2.34199, 53.8658]
t = np.arange(-1.5, 1.5, 0.003)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-1.5, 1.5, 0.003)
t2=np.linspace(-1.5, 1.5, 0.003)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -4.08038, 55.2704]
t = np.arange(0.0, 4.0, 0.004)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(0.0, 4.0, 0.004)
t2=np.linspace(0.0, 4.0, 0.004)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -4.32395, 55.4605]
t = np.arange(-2.0, 2.0, 0.004)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-2.0, 2.0, 0.004)
t2=np.linspace(-2.0, 2.0, 0.004)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -3.8, 55.0]
t = np.arange(0.0, 10.0, 0.01)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(0, 10.0, 0.01)
t2=np.linspace(0.0, 10.0, 0.01)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
"""randomly pick an initial condition"""
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [9.0, -6.8,49.5]
t = np.arange(-0, 5.0, 0.005)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-0.0, 5.0, 0.005)
t2=np.linspace(-0.0, 5.0, 0.005)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()

"""collect data from the one-cycle region"""
dataTrial1_9_mi6dot8_49dot5_ = np.zeros((400,400))

for i in range(399):
    for j in range(399):
        dataTrial1_9_mi6dot8_49dot5_[i,j]= Z[200+i,200+j]
        
""" plot the Recurrence Plot for the new region of data"""
D = np.zeros((400,400))
t1=np.arange(0, 2.0, 0.005)
t2=np.arange(-0, 2.0, 0.005)
T1,T2=np.meshgrid(t1,t2)
for i in range(399):
    for j in range(399):
            
            if dataTrial1_9_mi6dot8_49dot5_[i,j] > delta_h or dataTrial1_9_mi6dot8_49dot5_[i,j] < delta_l:
                D[i,j] = 1
            else:
                D[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,D)
plt.xlabel('time')
plt.ylabel('time')
plt.show()

for i in range(399):
    
    D[i,:]=sorted(dataTrial1_9_mi6dot8_49dot5_[i,:])

"the 2 points which are the closetest are chosen"
if min(D[0:398,2]) < 0.006 and min(D[0:398,2]) < 0.006:
    print(np.argmin(D[0:399-1,2]))
else:
    print( "nothing" )
"""find the corresponding (x, y, z) vector which corresponds to the initial condition"""
print(states[200+np.argmin(D[0:399-1,2]),0],states[200+np.argmin(D[0:399-1,2]),1],states[200+np.argmin(D[0:399-1,2]),2])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# 13
# 3.422928175711023 5.716414515405686 25.769889846616696

# %%
"""Test of initial condition obtained previously"""

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint,quad,trapz
import math
from IPython.display import Image # for Notebook
from IPython.core.display import HTML
from mpl_toolkits.mplot3d import Axes3D

sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [3.42293,	5.71641, 25.7699]
t = np.arange(-0, 1.0, 0.001)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative


states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-0.0, 5.0, 0.005)
t2=np.linspace(-0.0, 5.0, 0.005)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0

plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
 """randomly pick an initial condition"""
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [9.0, -6.9,49.5]
t = np.arange(-0, 5.0, 0.005)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative


states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-0.0, 5.0, 0.005)
t2=np.linspace(-0.0, 5.0, 0.005)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0

plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()

"""collect data from the one-cycle region"""
dataTrial1_9_mi6dot9_49dot5_ = np.zeros((400,400))

for i in range(399):
    for j in range(399):
        dataTrial1_9_mi6dot9_49dot5_[i,j]= Z[600+i,600+j]
        
""" plot the Recurrence Plot for the new region of data"""
D = np.zeros((400,400))
t1=np.arange(0, 400*0.005, 0.005)
t2=np.arange(-0, 400*0.005, 0.005)
T1,T2=np.meshgrid(t1,t2)
for i in range(399):
    for j in range(399):
            
            if dataTrial1_9_mi6dot9_49dot5_[i,j] > delta_h or dataTrial1_9_mi6dot9_49dot5_[i,j] < delta_l:
                D[i,j] = 1
            else:
                D[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,D)
plt.xlabel('time')
plt.ylabel('time')
plt.show()

for i in range(399):
    
    D[i,:]=sorted(dataTrial1_9_mi6dot9_49dot5_[i,:])

"the 2 points which are the closetest are chosen"
if min(D[0:398,2]) < 0.006 and min(D[0:398,2]) < 0.006:
    print(np.argmin(D[0:398,2]))
else:
    print( "nothing" )
"""find the corresponding (x, y, z) vector which corresponds to the initial condition"""
print(states[600+np.argmin(D[0:399-1,2]),0],states[600+np.argmin(D[0:399-1,2]),1],states[600+np.argmin(D[0:399-1,2]),2])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# 351
# -2.7669704109684923 -1.186174094786631 35.50996580176476

# %%
"""Test of initial condition obtained previously"""

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint,quad,trapz
import math
from IPython.display import Image # for Notebook
from IPython.core.display import HTML
from mpl_toolkits.mplot3d import Axes3D

sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [-2.7669704109684923, -1.186174094786631, 35.50996580176476]
t = np.arange(-0, 20.0, 0.01)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative


states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-0.0, 5.0, 0.005)
t2=np.linspace(-0.0, 5.0, 0.005)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((2000,2000))
Z2=np.zeros((2000,2000))
delta_h = 2
delta_l = 0
for i in range(1999):
    for j in range(1999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0

plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()

fig = plt.figure()
ax = plt.axes()
ax.plot(t, states[:,0])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
