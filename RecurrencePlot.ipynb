# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint,quad,trapz
import math
from IPython.display import Image # for Notebook
from IPython.core.display import HTML
from mpl_toolkits.mplot3d import Axes3D

sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -2.34199, 53.8658]
t = np.arange(-1.5, 1.5, 0.003)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-1.5, 1.5, 0.003)
t2=np.linspace(-1.5, 1.5, 0.003)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -4.08038, 55.2704]
t = np.arange(0.0, 4.0, 0.004)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(0.0, 4.0, 0.004)
t2=np.linspace(0.0, 4.0, 0.004)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -4.32395, 55.4605]
t = np.arange(-2.0, 2.0, 0.004)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-2.0, 2.0, 0.004)
t2=np.linspace(-2.0, 2.0, 0.004)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sigma = 16.0
rho = 45.0
beta = 4.0
state0 = [10.0, -3.8, 55.0]
t = np.arange(-4.0, 4.0, 0.008)

def Lorenz(fun,t):
    x,y,z=fun
    derivative=[sigma * (y - x), x * (rho - z) - y, x * y - beta * z]
    return derivative
    

states = odeint(Lorenz, state0, t)
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.xlim(-40,40)
plt.ylim(-40,40)
plt.show()

t1=np.linspace(-4.0, 4.0, 0.008)
t2=np.linspace(-4.0, 4.0, 0.008)
T1,T2=np.meshgrid(t,t)
Z=np.zeros((1000,1000))
Z2=np.zeros((1000,1000))
delta_h = 2
delta_l = 0
for i in range(999):
    for j in range(999):
            Z[i,j]=math.sqrt((states[:,0][i]-states[:,0][j])**2)
            if Z[i,j] > delta_h or Z[i,j] < delta_l:
                Z2[i,j] = 1
            else:
                Z2[i,j] = 0
                    
plt.figure(figsize=(12,12))
plt.pcolormesh(T1,T2,Z2)
plt.xlabel('time')
plt.ylabel('time')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
